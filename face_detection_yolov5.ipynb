# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/augmented_face_dataset.zip' -d '/content/augmented_face_dataset'

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16450, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 16450 (delta 17), reused 29 (delta 11), pack-reused 16408
# Receiving objects: 100% (16450/16450), 15.02 MiB | 19.90 MiB/s, done.
# Resolving deltas: 100% (11280/11280), done.
# /content/yolov5

# %% [markdown]
# train from scratch

# %%
# !python train.py --img 640 --batch 64 --epochs 30 --data /content/face_dataset/data.yaml --weights yolov5s.pt

# %% [markdown]
# finetune

# %%
# !python train.py --img 640 --batch 64 --epochs 50 --data /content/augmented_face_dataset/data.yaml --weights /content/drive/MyDrive/pretrained.pt
# Out:
# 2024-02-24 13:28:01.775855: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-24 13:28:01.775910: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-24 13:28:01.777286: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
